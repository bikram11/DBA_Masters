# %%
import pandas as pd

df = pd.read_csv('/media/bikram/Samsung_T5/DBA/Driver_Behavior/D6_merged.csv')

# %%
df
# Out:
#       Unnamed: 0  Timestamp (seconds)  Speed (km/h)
# 0              0                18.42          68.3  \
# 1              1                19.37          68.5
# 2              2                20.36          68.0
# 3              3                21.37          68.4
# 4              4                22.36          68.2
# ...          ...                  ...           ...
# 4519         722               748.73          80.1
# 4520         723               749.75          80.3
# 4521         724               750.73          81.1
# 4522         725               751.76          83.4
# 4523         726               752.75          85.1
#
#       Latitude coordinate (degrees)  Longitude coordinate (degrees)
# 0                         40.516933                       -3.408077  \
# 1                         40.517075                       -3.408206
# 2                         40.517216                       -3.408337
# ...

# %%
df['class'] = df[['Ratio normal (base 1)','Ratio drowsy (base 1)','Ratio aggressive (base 1)']].idxmax(axis=1)

# %%
df
# Out:
#       Unnamed: 0  Timestamp (seconds)  Speed (km/h)
# 0              0                18.42          68.3  \
# 1              1                19.37          68.5
# 2              2                20.36          68.0
# 3              3                21.37          68.4
# 4              4                22.36          68.2
# ...          ...                  ...           ...
# 4519         722               748.73          80.1
# 4520         723               749.75          80.3
# 4521         724               750.73          81.1
# 4522         725               751.76          83.4
# 4523         726               752.75          85.1
#
#       Latitude coordinate (degrees)  Longitude coordinate (degrees)
# 0                         40.516933                       -3.408077  \
# 1                         40.517075                       -3.408206
# 2                         40.517216                       -3.408337
# ...

# %%
df['class'] = df['class'].str.split(" ")

# %%
for i in range(len(df)):
    df['class'][i]=df['class'][i][1]
# Out:
# /tmp/ipykernel_203998/2040622451.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['class'][i]=df['class'][i][1]
# /tmp/ipykernel_203998/2040622451.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['class'][i]=df['class'][i][1]
# /tmp/ipykernel_203998/2040622451.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['class'][i]=df['class'][i][1]
# ...

# %%
df
# Out:
#       Unnamed: 0  Timestamp (seconds)  Speed (km/h)
# 0              0                18.42          68.3  \
# 1              1                19.37          68.5
# 2              2                20.36          68.0
# 3              3                21.37          68.4
# 4              4                22.36          68.2
# ...          ...                  ...           ...
# 4519         722               748.73          80.1
# 4520         723               749.75          80.3
# 4521         724               750.73          81.1
# 4522         725               751.76          83.4
# 4523         726               752.75          85.1
#
#       Latitude coordinate (degrees)  Longitude coordinate (degrees)
# 0                         40.516933                       -3.408077  \
# 1                         40.517075                       -3.408206
# 2                         40.517216                       -3.408337
# ...

# %%
list(set(list(df)))
# Out:
# ['Vertical accuracy (degrees)',
#  'Latitude coordinate (degrees)',
#  'Acceleration in Y (Gs)',
#  'Altitude (meters)',
#  'Time of impact to ahead vehicle (seconds) [distance related to own speed]',
#  'Course (degrees)',
#  'Acceleration in X filtered by KF (Gs)',
#  'Ratio aggressive (base 1)',
#  'X: car position relative to lane center (meters)',
#  'GPS Longitude used to query OSM (degrees)',
#  'Speed (km/h)',
#  'Reliability of obtained maxspeed (0=unknown, 1=reliable, 2=used previously obtained maxspeed,3=estimated by type of road)',
#  'Maximum allowed speed of current road (km/h)',
#  'Timestamp (seconds)',
#  'Ratio normal (base 1)',
#  'Ratio drowsy (base 1)',
#  'GPS speed (km/h) [same as in RAW GPS]',
#  'Difcourse: course variation (degrees)',
#  'W: road width (meters)',
#  'State of the lane det. algorithm [-1=calibrating, 0=initializing, 1=undetected, 2=detected/running]',
#  'Phi: car angle relative to lane curvature (degrees)',
# ...

# %%
# from sklearn.preprocessing import LabelEncoder
# label_encoder = LabelEncoder()
# df['class_coded']=label_encoder.fit_transform(df['class'])

# %%
# corlist = abs(df.corr()['class'].sort_values(ascending=False))
# corlist

# %%
df = df.drop([  'Number of detected vehicles in this frame (traffic)',
 'Number of lanes in current road', 'Unnamed: 0',
 'Boolean of system activated (1 if >50km/h)', 'Horizontal accuracy (degrees)',
 'GPS Latitude used to query OSM (degrees)', 'Acceleration in Y filtered by KF (Gs)',
 'Estimated current lane (1=right lane, 2=first left lane, 3=second left lane, etc) [experimental]', 'Distance to ahead vehicle in current lane (meters) [value -1 means no car is detected in front]',
 'OSM delay to answer query (seconds)', 'GPS speed (km/h) [same as in RAW GPS]',
 'Difcourse: course variation (degrees)',
 'W: road width (meters)',
 'State of the lane det. algorithm [-1=calibrating, 0=initializing, 1=undetected, 2=detected/running]',
 'Phi: car angle relative to lane curvature (degrees)', 'Ratio normal (base 1)',
 'Ratio drowsy (base 1)', 'Reliability of obtained maxspeed (0=unknown, 1=reliable, 2=used previously obtained maxspeed,3=estimated by type of road)', 'Altitude (meters)',
 'Time of impact to ahead vehicle (seconds) [distance related to own speed]',
 'Course (degrees)',
 'Acceleration in X filtered by KF (Gs)',
 'Ratio aggressive (base 1)',
 'X: car position relative to lane center (meters)',
 'GPS Longitude used to query OSM (degrees)','Vertical accuracy (degrees)',  'Type of road (motorway, trunk, secondary...)'], axis=1)

# %%
df['Driver']='D6'

# %%
df
# Out:
#       Timestamp (seconds)  Speed (km/h)  Latitude coordinate (degrees)
# 0                   18.42          68.3                      40.516933  \
# 1                   19.37          68.5                      40.517075
# 2                   20.36          68.0                      40.517216
# 3                   21.37          68.4                      40.517357
# 4                   22.36          68.2                      40.517494
# ...                   ...           ...                            ...
# 4519               748.73          80.1                      40.515694
# 4520               749.75          80.3                      40.515526
# 4521               750.73          81.1                      40.515354
# 4522               751.76          83.4                      40.515175
# 4523               752.75          85.1                      40.514988
#
#       Longitude coordinate (degrees)  Acceleration in X (Gs)
# ...

# %%
df.to_csv('/media/bikram/Samsung_T5/DBA/filtered_dataset/D6_clean.csv')
